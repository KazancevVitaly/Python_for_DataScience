# %% [markdown]
# # Домашняя работа. Урок 2.
# ## Казанцев Виталий
# ### Задание1
# ***В чём различие между зависимыми и независимыми выборками?***
#
# ### Задание 2
# ***Когда применяются параметрические статистические критерии, а когда — их непараметрические аналоги?***

# %% [markdown]
# #### Задание 1
# ***Ответ:***
# Зависимые выборки характеризуется тем, что каждаму элементу из выборки X соответствует элемент из выборки Y и наоборот. Например в выборке X дети определенного возраста, а в другой брат или сестра для каждого ребенка. Напротив в независимых выборках подобная закономерность отсутствует. Например медики и математики.

# %% [markdown]
# #### Задание 2
# ***Ответ:***
#
# **Статистический критерий -** это математическое правило, на основании которого принимается та или иная статистическая гипотеза с определенным уровнем значимости
# **Параметрические критерии** Группа статистических критериев, которые включают в расчет параметры вероятностного распределения признака (средние и дисперсии).
#
# * t-критерий Стьюдента
# * Критерий Фишера
# * Критерий отношения правдоподобия
# * Критерий Романовского
#
# Применяются в задачах проверки параметрических гипотез и применимы только тогда когда признак измерим и подчиняется нормальному распределению.
#
# **Непараметрические критерии** Группа статистических критериев, которые не включают в расчёт параметры вероятностного распределения и основаны на оперировании частотами или рангами.
#
# * Q-критерий Розенбаума
# * U-критерий Манна — Уитни
# * Критерий Уилкоксона
# * Критерий Пирсона
# * Критерий Колмогорова — Смирнова
#
# Непараметрические критерии не основаны на оценке параметров распределения и вообще не требуют, чтобы данные подчинялись какому-то определенному типу распределения.  Непараметрические критерии дают более грубые оценки, чем параметрические, но являются более универсальными. А параметрические методы более точны, но лишь в случае, если правильно определено распределение совокупности.
